# %% [markdown]
# <a href="https://colab.research.google.com/github/Hlmdul/PraktikumDM/blob/main/Praktikum3DM_Hilmi_Abdullah_0110223313_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Committed to https://github.com/Hlmdul/PraktikumDM

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/BL-Flickr-Images-Book.csv')
df
# Out:
#       Identifier             Edition Statement      Place of Publication  \
# 0            206                           NaN                    London
# 1            216                           NaN  London; Virtue & Yorston
# 2            218                           NaN                    London
# 3            472                           NaN                    London
# 4            480  A new edition, revised, etc.                    London
# ...          ...                           ...                       ...
# 8282     4158088                           NaN                    London
# 8283     4158128                           NaN                     Derby
# 8284     4159563                           NaN                    London
# 8285     4159587                           NaN       Newcastle upon Tyne
# 8286     4160339                           NaN                    London
#
#      Date of Publication                Publisher  \
# ...

# %%
# Melihat datatype dan spesifik pada dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8287 entries, 0 to 8286
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Identifier              8287 non-null   int64
#  1   Edition Statement       773 non-null    object
#  2   Place of Publication    8287 non-null   object
#  3   Date of Publication     8106 non-null   object
#  4   Publisher               4092 non-null   object
#  5   Title                   8287 non-null   object
#  6   Author                  6509 non-null   object
#  7   Contributors            8287 non-null   object
#  8   Corporate Author        0 non-null      float64
#  9   Corporate Contributors  0 non-null      float64
#  10  Former owner            1 non-null      object
#  11  Engraver                0 non-null      float64
#  12  Issuance type           8287 non-null   object
#  13  Flickr URL              8287 non-null   object
# ...

# %%
# mengecek apakah ada missing value
df.isnull().sum()
# Out:
# Identifier                   0
# Edition Statement         7514
# Place of Publication         0
# Date of Publication        181
# Publisher                 4195
# Title                        0
# Author                    1778
# Contributors                 0
# Corporate Author          8287
# Corporate Contributors    8287
# Former owner              8286
# Engraver                  8287
# Issuance type                0
# Flickr URL                   0
# Shelfmarks                   0
# dtype: int64

# %%
# menghapus data yang tidak diperlukan
col_to_drop = ['Edition Statement', 'Corporate Author', 'Corporate Contributors', 'Former owner', 'Engraver']
df.drop(columns=col_to_drop, inplace=True)
df
# Out:
#       Identifier      Place of Publication Date of Publication  \
# 0            206                    London         1879 [1878]
# 1            216  London; Virtue & Yorston                1868
# 2            218                    London                1869
# 3            472                    London                1851
# 4            480                    London                1857
# ...          ...                       ...                 ...
# 8282     4158088                    London                1838
# 8283     4158128                     Derby            1831, 32
# 8284     4159563                    London           [1806]-22
# 8285     4159587       Newcastle upon Tyne                1834
# 8286     4160339                    London             1834-43
#
#                     Publisher  \
# 0            S. Tinsley & Co.
# 1                Virtue & Co.
# 2       Bradbury, Evans & Co.
# 3               James Darling
# 4        Wertheim & Macintosh
# ...

# %%
# Menjadikan Identifier sebagai index untuk memudahkan mengambil sebuah data
df.set_index('Identifier', inplace=True)
df
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 206                           London         1879 [1878]
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
# 472                           London                1851
# 480                           London                1857
# ...                              ...                 ...
# 4158088                       London                1838
# 4158128                        Derby            1831, 32
# 4159563                       London           [1806]-22
# 4159587          Newcastle upon Tyne                1834
# 4160339                       London             1834-43
#
#                           Publisher  \
# Identifier
# 206                S. Tinsley & Co.
# 216                    Virtue & Co.
# 218           Bradbury, Evans & Co.
# 472                   James Darling
# 480            Wertheim & Macintosh
# ...

# %%
# Mengubah nama kolom
df.rename(columns={
    'Place of Publication': 'Tempat_Penerbitan',
    'Date of Publication': 'Tahun_Penerbitan',
    'Publisher': 'Penerbit',
    'Title': 'Judul',
    'Author': 'Penulis',
    'Contributors': 'Kontributor',
    'Issuance type': 'Jenis_Penerbitan',
    'Flickr URL': 'URL_Flickr',
    'Shelfmarks': 'penanda_Rak'
}, inplace=True)

# Tampilkan DataFrame setelah perubahan nama kolom
df
# Out:
#                    Tempat_Penerbitan Tahun_Penerbitan  \
# Identifier
# 206                           London      1879 [1878]
# 216         London; Virtue & Yorston             1868
# 218                           London             1869
# 472                           London             1851
# 480                           London             1857
# ...                              ...              ...
# 4158088                       London             1838
# 4158128                        Derby         1831, 32
# 4159563                       London        [1806]-22
# 4159587          Newcastle upon Tyne             1834
# 4160339                       London          1834-43
#
#                            Penerbit  \
# Identifier
# 206                S. Tinsley & Co.
# 216                    Virtue & Co.
# 218           Bradbury, Evans & Co.
# 472                   James Darling
# 480            Wertheim & Macintosh
# ...                             ...
# ...

# %% [markdown]
# Gunakan Dataset dari kuesioner di Elena
# 1. Lakukan proses cleaning yang dibutuhkan (jelaskan tahapan dan hasil)
# 2. Eksplorasi data tersebut, tunjukkan nilai min, max, rata-rata, stdev, dan histogram dari masing-masing variabel
# 3. Lakukan Transformasi
# 	a) buat variabel baru, yaitu BMI
# 	b) buat grouping berdasarkan BMI (kurang, normal, overweight, obesitas)
# 	c) hitung rata2 berat dan tinggi dari tiap jenis kelamin
# 	d) lakukan 3 jenis normalisasi data

# %%
df2 = pd.read_csv('Kuesioner.csv', delimiter=';')
df2
# Out:
#    Jenis Kelamin Tinggi (dalam cm) Berat (dalam kg)
# 0      Perempuan               155               50
# 1      Laki-laki               169              NaN
# 2      Perempuan               163               50
# 3      Laki-laki               170               62
# 4      Perempuan               155               58
# ..           ...               ...              ...
# 71     Perempuan            160 cm            44 kg
# 72     Perempuan               158               56
# 73     Laki-laki               178               68
# 74     Perempuan               153               47
# 75     Perempuan               157               50
#
# [76 rows x 3 columns]

# %%
# Mengubah nama kolom untuk kemudahan mengakses data pada kolom
df2.rename(columns={
    'Jenis Kelamin': 'jenis_kelamin',
    'Tinggi (dalam cm)': 'tinggi',
    'Berat (dalam kg)': 'berat'
    }, inplace=True)
df2
# Out:
#    jenis_kelamin  tinggi  berat
# 0      Perempuan     155     50
# 1      Laki-laki     169    NaN
# 2      Perempuan     163     50
# 3      Laki-laki     170     62
# 4      Perempuan     155     58
# ..           ...     ...    ...
# 71     Perempuan  160 cm  44 kg
# 72     Perempuan     158     56
# 73     Laki-laki     178     68
# 74     Perempuan     153     47
# 75     Perempuan     157     50
#
# [76 rows x 3 columns]

# %%
# Mencari data Nan
df2.isnull().sum()
# Out:
# jenis_kelamin    0
# tinggi           0
# berat            1
# dtype: int64

# %% [markdown]
# Ditemukan 1 baris data yang mengandung Nan pada kolom berat, perlakuan selanjutnya adalah menghapus baris tersebut. penghapusan baris dilakukan atas pertimbangan 1 baris data yang mengandung nan tidak terlalu signifikan
# secara proporsi terhadap keseluruhan data yang memiliki 76 baris data

# %%
# menghapus baris yang mengandung nan
df2.dropna(subset=['berat'], inplace=True)
df2
# Out:
#    jenis_kelamin  tinggi  berat
# 0      Perempuan     155     50
# 2      Perempuan     163     50
# 3      Laki-laki     170     62
# 4      Perempuan     155     58
# 5      Perempuan   164cm   51kg
# ..           ...     ...    ...
# 71     Perempuan  160 cm  44 kg
# 72     Perempuan     158     56
# 73     Laki-laki     178     68
# 74     Perempuan     153     47
# 75     Perempuan     157     50
#
# [75 rows x 3 columns]

# %%
# Mengecek tipe data pada kolom berat dan tinggi
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 75 entries, 0 to 75
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   jenis_kelamin  75 non-null     object
#  1   tinggi         75 non-null     object
#  2   berat          75 non-null     object
# dtypes: object(3)
# memory usage: 2.3+ KB

# %% [markdown]
# Dapat dilihat bahwa tipe data pada kolom tinggi dan berat belum berupa int atau float sehingga belum bisa diterapkan fungsi2 aritmatika. Untuk mengubah tipe data tersebut akan dilakukan method .to_numeric pada kolom tinggi dan berat, namun sebelum itu dapat dilihat bahwa terdapat inkonsistensi dalam penulisan data tinggi dan berat seperti adanya tambahan satuan kg pada berat, dan ada data yang menggunakan tanda baca koma (,) untuk pemisah digit desimal, bila langsung dipanggil method .to_numeric, data2 tersebut akan hilang sehingga dilakukan beberapa method .str.replace() untuk mengatasi inkonsistensi tersebut

# %%
# Menghilangkan Inkonsistensi penulisan data
df2['berat'] = df2['berat'].str.replace(' kg', '', regex=False)
df2['berat'] = df2['berat'].str.replace('kg', '', regex=False)
df2['berat'] = df2['berat'].str.replace(',', '.', regex=False)

df2['tinggi'] = df2['tinggi'].str.replace(' cm', '', regex=False)
df2['tinggi'] = df2['tinggi'].str.replace('cm', '', regex=False)
df2['tinggi'] = df2['tinggi'].str.replace(',', '.', regex=False)
df2
# Out:
#    jenis_kelamin tinggi berat
# 0      Perempuan    155    50
# 2      Perempuan    163    50
# 3      Laki-laki    170    62
# 4      Perempuan    155    58
# 5      Perempuan    164    51
# ..           ...    ...   ...
# 71     Perempuan    160    44
# 72     Perempuan    158    56
# 73     Laki-laki    178    68
# 74     Perempuan    153    47
# 75     Perempuan    157    50
#
# [75 rows x 3 columns]

# %%
# Mengubah tipe data pada kolom tinggi dan berat menjadi numeric
df2['tinggi'] = pd.to_numeric(df2['tinggi'], errors='coerce')
df2['berat'] = pd.to_numeric(df2['berat'], errors='coerce')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 75 entries, 0 to 75
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   jenis_kelamin  75 non-null     object
#  1   tinggi         75 non-null     float64
#  2   berat          75 non-null     int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.3+ KB

# %% [markdown]
# Selanjutnya dicari apakah ada data pencilan dengan menggunakan boxplot

# %%
df2.boxplot(column=['tinggi', 'berat'])
# Out:
# <Axes: >

# %% [markdown]
# Ditemukan outlier pada boxplot di atas, maka dilakukan investigasi mengenai posisi outlier dan apakah data outlier tersebut valid atau ada kesalahan input

# %%
q1_tinggi = df2['tinggi'].quantile(0.25)
q3_tinggi = df2['tinggi'].quantile(0.75)
iqr_tinggi = q3_tinggi - q1_tinggi

batas_atas_tinggi = q3_tinggi + 1.5 * iqr_tinggi
batas_bawah_tinggi = q1_tinggi - 1.5 * iqr_tinggi

outlier_tinggi_index = df2[(df2['tinggi'] > batas_atas_tinggi) | (df2['tinggi'] < batas_bawah_tinggi)]


q1_berat = df2['berat'].quantile(0.25)
q3_berat = df2['berat'].quantile(0.75)
iqr_berat = q3_berat - q1_berat
batas_atas_berat = q3_berat + 1.5 * iqr_berat
batas_bawah_berat = q1_berat - 1.5 * iqr_berat
outlier_berat_index = df2[(df2['berat'] > batas_atas_berat) | (df2['berat'] < batas_bawah_berat)]

# Tampilkan posisi outlier
print("Posisi outlier pada kolom 'tinggi': \n", outlier_tinggi_index)
print("\nPosisi outlier pada kolom 'berat': \n", outlier_berat_index)
print(batas_atas_tinggi,q3_tinggi, q1_tinggi, batas_bawah_tinggi)
print(batas_atas_berat,q3_berat, q1_berat, batas_bawah_berat)
# Out:
# Posisi outlier pada kolom 'tinggi':
#     jenis_kelamin  tinggi  berat
# 18     Laki-laki   220.0    100
# 45     Perempuan    16.0     55
#
# Posisi outlier pada kolom 'berat':
#     jenis_kelamin  tinggi  berat
# 18     Laki-laki   220.0    100
# 26     Laki-laki   172.0    130
# 35     Perempuan   167.0     90
# 53     Laki-laki   174.0    118
# 59     Perempuan   170.0     85
# 181.0 166.0 156.0 141.0
# 83.75 62.0 47.5 25.75

# %% [markdown]
# Dari data outlier yang ada pada kolom tinggi dan berat dapat dilihat bahwa pada baris dengan index 45 terlihat bahwa bbaris tersebut memiliki nilai tinggi 16.0 (cm) yang secara logika tidak mungkin seseorang memiliki berat 16 cm. sedangkan pada baris dengan index 18, terlihat baris tersebut memiliki nilai tinggi 220.0 (cm), diasumsikan sampel data adalah mahasiswa STT Nurul Fikri, data ini juga menimbulkan tanda tanya mengenai kevalidannya. Kedua data tersebut akan dihapus karena berpotensi memberikan pemahaman yang menyesatkan mengenai data. data outlier lain yang diidentifikasi terlihat seperti data yang valid, maka dipertahankan.

# %%
# Menghapus data tidak valid
df2.drop(index=[45, 18], inplace=True)
df2
# Out:
#    jenis_kelamin  tinggi  berat
# 0      Perempuan   155.0     50
# 2      Perempuan   163.0     50
# 3      Laki-laki   170.0     62
# 4      Perempuan   155.0     58
# 5      Perempuan   164.0     51
# ..           ...     ...    ...
# 71     Perempuan   160.0     44
# 72     Perempuan   158.0     56
# 73     Laki-laki   178.0     68
# 74     Perempuan   153.0     47
# 75     Perempuan   157.0     50
#
# [73 rows x 3 columns]

# %% [markdown]
# Selanjutnya dilakukan identifikasi agregat data dengan menggunakan method .describe() lalu dibuat plot histogram berdasarkan variabel tinggi dan berat

# %%
# Melihat nilai min, max, mean, dan stdev
df2.describe()
# Out:
#            tinggi       berat
# count   73.000000   73.000000
# mean   161.363014   56.876712
# std      6.710926   15.644439
# min    145.000000   37.000000
# 25%    156.000000   47.000000
# 50%    160.000000   53.000000
# 75%    166.000000   62.000000
# max    178.000000  130.000000

# %%
# import modul matplotlib pyplot
import matplotlib.pyplot as plt

# pembuatan histogram variabel 'tinggi'
data_tinggi = df2['tinggi']
n, bins, patches = plt.hist(data_tinggi, bins=5, color='blue', edgecolor='black')
plt.xlabel('Tinggi (cm)')
plt.ylabel('Frekuensi')
plt.title('Histogram Variabel Tinggi')

bin_centers = 0.5 * (bins[:-1] + bins[1:])
plt.xticks(bin_centers, ['{:.0f}-{:.0f}'.format(bins[i], bins[i+1]) for i in range(len(bins)-1)])

plt.show()

# %%
# pembuatan histogram variabel 'berat'
data_berat = df2['berat']
n, bins, patches = plt.hist(data_berat, bins=5, color='green', edgecolor='black')
plt.xlabel('Berat (kg)')
plt.ylabel('Frekuensi')
plt.title('Histogram Variabel Berat')

bin_centers = 0.5 * (bins[:-1] + bins[1:])
plt.xticks(bin_centers, ['{:.0f}-{:.0f}'.format(bins[i], bins[i+1]) for i in range(len(bins)-1)])

plt.show()

# %%
# Membuat Variabel baru BMI
df2['BMI'] = df2['berat'] / (df2['tinggi']/100)**2
df2
# Out:
#    jenis_kelamin  tinggi  berat        BMI
# 0      Perempuan   155.0     50  20.811655
# 2      Perempuan   163.0     50  18.818924
# 3      Laki-laki   170.0     62  21.453287
# 4      Perempuan   155.0     58  24.141519
# 5      Perempuan   164.0     51  18.961927
# ..           ...     ...    ...        ...
# 71     Perempuan   160.0     44  17.187500
# 72     Perempuan   158.0     56  22.432303
# 73     Laki-laki   178.0     68  21.461937
# 74     Perempuan   153.0     47  20.077748
# 75     Perempuan   157.0     50  20.284799
#
# [73 rows x 4 columns]

# %% [markdown]
# Selanjutnya berdasarkan variabel baru BMI akan dilakukan Grouping dengan klasifikasi sebagai berikut:
#
#
# *   underweight (<18.5)
# *   normal (18.5-24.9)
# *   overweight (25.0-29.9)
# *   obesity (>29.9)

# %%
# Definisikan fungsi untuk klasifikasi BMI
def klasifikasi_bmi(bmi):
    if bmi < 18.5:
        return 'underweight'
    elif 18.5 <= bmi <= 24.9:
        return 'normal'
    elif 25.0 <= bmi <= 29.9:
        return 'overweight'
    else:
        return 'obesity'

# menerapkann fungsi ke kolom 'BMI' dan buat kolom baru 'klasifikasi_bmi'
df2['klasifikasi_bmi'] = df2['BMI'].apply(klasifikasi_bmi)

# grouping berdasarkan 'klasifikasi_bmi'
grouped_bmi = df2.groupby('klasifikasi_bmi')

# menampilkan agregat data berdasarkan grouping bmi
print(grouped_bmi.describe())

print('\nRata-rata tinggi badan berdasarkan klasifikasi BMI')
print(grouped_bmi['tinggi'].mean())
# Out:
#                 tinggi                                                    \
#                  count        mean       std    min    25%    50%    75%
# klasifikasi_bmi
# normal            51.0  161.637255  6.950596  145.0  157.0  160.0  166.0
# obesity            3.0  171.000000  3.605551  167.0  169.5  172.0  173.0
# overweight         5.0  159.400000  6.985700  151.0  156.0  160.0  160.0
# underweight       14.0  159.000000  4.169486  155.0  155.0  158.5  160.0
#
#                        berat              ...                 BMI             \
#                    max count        mean  ...    75%    max count       mean
# klasifikasi_bmi                           ...
# normal           178.0  51.0   56.117647  ...   60.0   78.0  51.0  21.379245
# obesity          174.0   3.0  112.666667  ...  124.0  130.0   3.0  38.396075
# overweight       170.0   5.0   69.600000  ...   72.0   85.0   5.0  27.294599
# underweight      169.0  14.0   43.142857  ...   45.0   49.0  14.0  17.054023
#
# ...

# %%
# Grouping berdasarkan Jenis Kelamin
grouped_jenis_kelamin = df2.groupby(['jenis_kelamin'])
grouped_jenis_kelamin.describe()
# Out:
#               tinggi                                                           \
#                count        mean       std    min    25%    50%    75%    max
# jenis_kelamin
# Laki-laki       14.0  171.107143  3.991234  166.0  168.0  170.0  173.5  178.0
# Perempuan       59.0  159.050847  4.896951  145.0  155.0  158.0  163.0  170.0
#
#               berat             ...                 BMI                       \
#               count       mean  ...    75%    max count       mean       std
# jenis_kelamin                   ...
# Laki-laki      14.0  74.000000  ...  73.75  130.0  14.0  25.177380  7.248411
# Perempuan      59.0  52.813559  ...  58.50   90.0  59.0  20.818232  3.433409
#
#
#                      min        25%        50%        75%        max
# jenis_kelamin
# Laki-laki      18.645344  21.455450  23.632475  24.518941  43.942672
# Perempuan      14.821343  18.639918  20.202020  22.456816  32.270788
#
# [2 rows x 24 columns]

# %%
# menampilkan rata-rata berat dan tinggi dari tiap jenis kelamin
print('Rata-rata tinggi dan berat berdasarkan jenis kelamin: ')
print(grouped_jenis_kelamin[['tinggi', 'berat']].mean())
# Out:
# Rata-rata tinggi dan berat berdasarkan jenis kelamin:
#                    tinggi      berat
# jenis_kelamin
# Laki-laki      171.107143  74.000000
# Perempuan      159.050847  52.813559

# %% [markdown]
# Terakhir akan dilakukan 3 tipe Normalisasi data yaitu
# 1. Min-Max Normalization
# 2. Z-Score Normalization
# 3. Scaling nilai desimal

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
# Min-Max Normalization

# Inisialisasi MinMaxScaler
scaler = MinMaxScaler()

# Lakukan Min-Max Normalization untuk kolom 'tinggi' dan 'berat'
df2[['tinggi_minmax', 'berat_minmax']] = scaler.fit_transform(df2[['tinggi', 'berat']])

# Menampilkan hasil normalisasi minmax
df2[['tinggi','tinggi_minmax', 'berat', 'berat_minmax']]
# Out:
#     tinggi  tinggi_minmax  berat  berat_minmax
# 0    155.0       0.303030     50      0.139785
# 2    163.0       0.545455     50      0.139785
# 3    170.0       0.757576     62      0.268817
# 4    155.0       0.303030     58      0.225806
# 5    164.0       0.575758     51      0.150538
# ..     ...            ...    ...           ...
# 71   160.0       0.454545     44      0.075269
# 72   158.0       0.393939     56      0.204301
# 73   178.0       1.000000     68      0.333333
# 74   153.0       0.242424     47      0.107527
# 75   157.0       0.363636     50      0.139785
#
# [73 rows x 4 columns]

# %%
# Z-Score

# Inisialisasi StandardScaler
scaler = StandardScaler()

# Lakukan Z-Score Normalization untuk kolom 'tinggi' dan 'berat'
df2[['tinggi_zscore', 'berat_zscore']] = scaler.fit_transform(df2[['tinggi', 'berat']])

# Menampilkan hasil normalisasi zscore
df2[['tinggi','tinggi_zscore', 'berat', 'berat_zscore']]
# Out:
#     tinggi  tinggi_zscore  berat  berat_zscore
# 0    155.0      -0.954719     50     -0.442605
# 2    163.0       0.245617     50     -0.442605
# 3    170.0       1.295910     62      0.329749
# 4    155.0      -0.954719     58      0.072298
# 5    164.0       0.395659     51     -0.378242
# ..     ...            ...    ...           ...
# 71   160.0      -0.204509     44     -0.828782
# 72   158.0      -0.504593     56     -0.056428
# 73   178.0       2.496246     68      0.715926
# 74   153.0      -1.254803     47     -0.635693
# 75   157.0      -0.654635     50     -0.442605
#
# [73 rows x 4 columns]

# %%
# Scaling Factor
scaling_factor_tinggi = 1000
scaling_factor_berat = 100

# Lakukan scaling nilai desimal untuk kolom 'tinggi' dan 'berat'
df2['tinggi_decimal'] = df2['tinggi'] / scaling_factor_tinggi
df2['berat_decimal'] = df2['berat'] / scaling_factor_berat

# Menampilkan hasil scaling nilai desimal
df2[['tinggi', 'tinggi_decimal', 'berat', 'berat_decimal']]
# Out:
#     tinggi  tinggi_decimal  berat  berat_decimal
# 0    155.0           0.155     50           0.50
# 2    163.0           0.163     50           0.50
# 3    170.0           0.170     62           0.62
# 4    155.0           0.155     58           0.58
# 5    164.0           0.164     51           0.51
# ..     ...             ...    ...            ...
# 71   160.0           0.160     44           0.44
# 72   158.0           0.158     56           0.56
# 73   178.0           0.178     68           0.68
# 74   153.0           0.153     47           0.47
# 75   157.0           0.157     50           0.50
#
# [73 rows x 4 columns]
